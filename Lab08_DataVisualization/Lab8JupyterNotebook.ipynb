# %% [markdown]
# # Lab 8: Data Visualizations using Python

# %% [markdown]
# 1. Download Python Anaconda & Jupyter notebook extension (on VSCode)
# 2. Create a virtual environment using conda.
#     ```bash
#         conda create --name info5100
#     ```
# 3. Activate the virtual environment
#     ```bash
#         conda activate info5100
#     ```
# 4. Install the following libraries:
#     - pandas
#     ```bash
#         pip install pandas
#     ```
#     - matplotlib
#     ```bash
#         pip install matplotlib
#     ```
#     - seaborn
#     ```bash
#         pip install seaborn
#     ```
# 5. All Set to Run This Jupyter Notebook (.ipynb file)
# 6. Select the Kernal in Top Right Corner (on VSCode)
# 7. In the end to exit from the virtual environment:
#     ```bash
#         conda deactivate
#     ```

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# If all the libraries are installed, the above cell should run successfully.

# %%
# Loading a dataset:
iris_dataframe = pd.read_csv('IrisDataset/Iris.csv')

# %%
iris_dataframe
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %%
iris_dataframe.head(-10)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 135  136            7.7           3.0            6.1           2.3
# 136  137            6.3           3.4            5.6           2.4
# 137  138            6.4           3.1            5.5           1.8
# 138  139            6.0           3.0            4.8           1.8
# 139  140            6.9           3.1            5.4           2.1
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 135  Iris-virginica
# 136  Iris-virginica
# 137  Iris-virginica
# 138  Iris-virginica
# 139  Iris-virginica
#
# [140 rows x 6 columns]

# %%
iris_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
iris_dataframe["Species"].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %% [markdown]
# ## Line Plot
#
# ### Univariate
# Visual representation of the relationship of a single column in a dataset.

# %%
plt.plot(iris_dataframe["Id"], iris_dataframe['SepalWidthCm'])
plt.title("Iris Sepal Length")
plt.xlabel("Id")
plt.ylabel("Sepal Width (cm)")
# plt.show()
# Out:
# Text(0, 0.5, 'Sepal Width (cm)')

# %%
# adding gird-lines
plt.grid(True)

plt.plot(iris_dataframe["Id"], iris_dataframe['SepalLengthCm'])
plt.title("Iris Sepal Length")
plt.xlabel("Id")
plt.ylabel("Sepal Length (cm)")
# Set x-axis for every 10 units
plt.xticks(range(0, max(iris_dataframe["Id"]) + 1, 10))  
plt.show()

# %% [markdown]
# ## Scatter Plot
#
# ### Bivariate
# Visual representation of the relationship between two variables in a dataset.

# %%
plt.grid(True)
plt.scatter(iris_dataframe["PetalLengthCm"], iris_dataframe["PetalWidthCm"])
plt.title("Iris Sepal Length vs Width")
plt.xlabel("Sepal Length (cm)")
plt.ylabel("Sepal Width (cm)")
# Out:
# Text(0, 0.5, 'Sepal Width (cm)')

# %% [markdown]
# ### Multivariate
# Visual representation of the relationship between three or more columns/ variables in a dataset.

# %%
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50

iris_species_color = {"Iris-setosa": "red", 
                      "Iris-versicolor": "green", 
                      "Iris-virginica":"blue"}

for species, species_color in iris_species_color.items():
    # creating a data frame for a specific value for 'Species' column:
    species_dataframe = iris_dataframe[iris_dataframe["Species"] == species]
    # parameter c - color
    plt.scatter(species_dataframe["PetalLengthCm"], species_dataframe["PetalWidthCm"], c = species_color, label=species)

plt.grid(True)
plt.title("Iris Sepal Length vs Width")
plt.xlabel("Sepal Length (cm)")
plt.ylabel("Sepal Width (cm)")
plt.legend()

# %% [markdown]
# ## Histograms

# %%
sns.histplot(data=iris_dataframe, x="SepalLengthCm")
plt.title("Sepal Length Distribution")
plt.xlabel("Sepal Length (cm)")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
sns.histplot(data=iris_dataframe, x="SepalLengthCm")
plt.title("Sepal Length Distribution")
plt.grid(axis="y")
plt.xlabel("Sepal Length (cm)")
plt.ylabel("Count")
plt.yticks(range(0, 30, 2))
# Out:
# ([<matplotlib.axis.YTick at 0x121f13250>,
#   <matplotlib.axis.YTick at 0x121d20a50>,
#   <matplotlib.axis.YTick at 0x121d211d0>,
#   <matplotlib.axis.YTick at 0x121d21950>,
#   <matplotlib.axis.YTick at 0x121d220d0>,
#   <matplotlib.axis.YTick at 0x121d22850>,
#   <matplotlib.axis.YTick at 0x120ba7b10>,
#   <matplotlib.axis.YTick at 0x121f38e10>,
#   <matplotlib.axis.YTick at 0x121f39590>,
#   <matplotlib.axis.YTick at 0x121f39d10>,
#   <matplotlib.axis.YTick at 0x121f3a490>,
#   <matplotlib.axis.YTick at 0x121f3ac10>,
#   <matplotlib.axis.YTick at 0x121f3b390>,
#   <matplotlib.axis.YTick at 0x121f3bb10>,
#   <matplotlib.axis.YTick at 0x121afc2d0>],
#  [Text(0, 0, '0'),
#   Text(0, 2, '2'),
#   Text(0, 4, '4'),
#   Text(0, 6, '6'),
#   Text(0, 8, '8'),
#   Text(0, 10, '10'),
#   Text(0, 12, '12'),
#   Text(0, 14, '14'),
#   Text(0, 16, '16'),
#   Text(0, 18, '18'),
#   Text(0, 20, '20'),
#   Text(0, 22, '22'),
#   Text(0, 24, '24'),
#   Text(0, 26, '26'),
#   Text(0, 28, '28')])

# %% [markdown]
# ## Pair Plot
# Introduce pairwise relationships.

# %%
sns.pairplot(iris_dataframe, hue="Species")
plt.show()

# %% [markdown]
# ## Box Plots

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x="Species", y="SepalLengthCm", data=iris_dataframe, palette="Set3")

# Add labels and title
plt.title("Box Plot of Sepal Length by Species")
plt.xlabel("Species")
plt.ylabel("Sepal Length (cm)")
plt.show()
# Out:
# /var/folders/8p/6g2xm1zj7nv54n8ryjkbhcw40000gn/T/ipykernel_77355/1198724479.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Species", y="SepalLengthCm", data=iris_dataframe, palette="Set3")

# %% [markdown]
# ## Swarm Plot + Box Plot

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x="Species", y="SepalLengthCm", data=iris_dataframe, palette="pastel")
sns.swarmplot(x="Species", y="SepalLengthCm", data=iris_dataframe, color=".25")
plt.title("Box and Swarm Plot of Petal Width by Species")
plt.xlabel("Species")
plt.ylabel("Petal Width (cm)")
plt.show()
# Out:
# /var/folders/8p/6g2xm1zj7nv54n8ryjkbhcw40000gn/T/ipykernel_77355/3450600594.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Species", y="SepalLengthCm", data=iris_dataframe, palette="pastel")

# %% [markdown]
# ## Kernel Density Plot (KDE)
#
# KDE plot helps to visualize the distribution of data in a dataset

# %%
# Create a KDE plot
plt.figure(figsize=(8, 6))
sns.kdeplot(data=iris_dataframe, x="SepalLengthCm", hue="Species", fill=True, common_norm=False, palette="crest", alpha=0.2)

# Add labels and title
plt.title("Kernel Density Plot of Sepal Length by Species")
plt.xlabel("Sepal Length (cm)")
plt.ylabel("Density")
plt.show()

# %% [markdown]
# ## Violin Plot (Box Plot + KDE)
#
# A statistical graphic that shows the distribution of numerical data by combining a box plot and a kernel density plot.

# %%
sns.violinplot(x='Species', y='PetalWidthCm', data=iris_dataframe)
plt.title('Violin Plot of Petal Width by Species')
plt.show()

# %% [markdown]
# ## Correlation Heat Maps

# %%
correlation = iris_dataframe.iloc[:, :-1].corr()
sns.heatmap(correlation, annot=True, cmap='coolwarm')
plt.title('Correl ation Heatmap')
plt.show()

# %% [markdown]
# ## Best Practices
#
# 1. Proper labeling for the axes.
# 2. Color choice considerations.
# 3. Scale and proportion
